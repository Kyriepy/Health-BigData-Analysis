# %%
# 1-1 연습문제

# 변수와 데이터 포멧팅을 이용해 본인을 소개해 보세요.

name = "최민식"
age = 24
dep = "컴퓨터공학부"
pos = "4학년"
hob = "게임"

print("안녕하세요 \n")
print("저의 이름은 ", name, "입니다.\n")
print("간단하게 제 소개를 하고자 합니다.\n")
print("-------------------------------\n")
print('이름 : ' + name + '\n')
print('나이 : ' + str(age) + '\n')
print('소속 : %s\n' % dep)
print('직위 : %s\n' % pos)
print(f'취미 : {hob}')
# Out:
# 안녕하세요
#
# 저의 이름은  최민식 입니다.
#
# 간단하게 제 소개를 하고자 합니다.
#
# -------------------------------
#
# 이름 : 최민식
#
# 나이 : 24
#
# 소속 : 컴퓨터공학부
#
# 직위 : 4학년
#
# 취미 : 게임

# %%
# 1-2 연습문제

# 역명을 리스트로 만들고 2번째 역명을 표시해 보세요.

station = ["시청", "서울역", "용산", "노량진"]

print(f'역번호 : 2, 역명 : {station[1]}')
# Out:
# 역번호 : 2, 역명 : 서울역
