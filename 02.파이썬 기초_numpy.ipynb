# %%
# !pip install numpy
# Out:
# 'pip'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
import numpy as np

# %%
num1 = [1,2,3,4]
num2 = [5,6,7,8]

num = [num1, num2]

num
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8]]

# %%
num1 + num2
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
num1 = np.array(num1)
num2 = np.array(num2)

num1
# Out:
# array([1, 2, 3, 4])

# %%
num1 + num2
# Out:
# array([ 6,  8, 10, 12])

# %%
num1.sum()
# Out:
# np.int64(10)

# %%
num = np.array([num1, num2])

num
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
num.shape
# Out:
# (2, 4)

# %%
num[1,3]
# Out:
# np.int64(8)

# %%
num3 = num[:2, :2]
num3
# Out:
# array([[1, 2],
#        [5, 6]])

# %%
num3 = num[0:, 1:]
num3
# Out:
# array([[2, 3, 4],
#        [6, 7, 8]])

# %%
num.sum(axis=0)
# Out:
# array([ 6,  8, 10, 12])

# %%
num.sum(axis=1)
# Out:
# array([10, 26])
