# %% [markdown]
# # 보건빅데이터분석 day 1

# %%
# 셀에 아래 내용을 입력하고 재생 버튼 클릭!
# %pip install pandas numpy seaborn matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

print("라이브러리 로드 성공!")
# Out:
# 라이브러리 로드 성공!

# %%
myscore = input('성적은')
myscore = int(myscore)

if (myscore >= 80):
    print("well done.")
else:
    print("more")
# Out:
# well done.

# %% [markdown]
# ## 2. 반복문

# %%
cal = 0

for i in range(101):
    cal += 1
    print(i)

# %%
test = [1,2,3,4]

for i in test:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
name = ['민식', '휘수']

for i in enumerate(name):
    print(i)
type(i)
# Out:
# (0, '민식')
# (1, '휘수')
# tuple

# %%
def avg(x,y):
    print((x+y)/2)
    
avg(6,5)
# Out:
# 5.5

# %%
def avg1(x,y):
    return ((x+y)/2)

a = avg1(4,5)

print(a)
# Out:
# 4.5
