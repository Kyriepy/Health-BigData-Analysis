# %% [markdown]
# # ⌨️ VS Code Jupyter Notebook 핵심 단축키 요약
#
# 주피터 노트북은 **명령 모드(Esc)**와 **편집 모드(Enter)** 두 가지 상태가 있습니다. 이를 구분해서 사용하면 훨씬 빠릅니다.
#
# ---
#
# ## 1. 셀 실행 및 생성 (가장 중요)
# | 단축키 | 기능 |
# | :--- | :--- |
# | **`Shift + Enter`** | 현재 셀을 실행하고 **다음 셀로 이동** (없으면 생성) |
# | **`Ctrl + Enter`** | 현재 셀만 실행하고 해당 위치에 머무름 |
# | **`Alt + Enter`** | 현재 셀을 실행하고 **바로 아래에 새 셀 삽입** |
# | **`A`** | 현재 셀 **위에** 새 셀 추가 (Above) |
# | **`B`** | 현재 셀 **아래에** 새 셀 추가 (Below) |
#
# ## 2. 셀 타입 변경 및 관리
# | 단축키 | 기능 |
# | :--- | :--- |
# | **`M`** | 셀을 **마크다운(문서)** 모드로 변경 |
# | **`Y`** | 셀을 **코드(Python)** 모드로 변경 |
# | **`D, D`** | 선택한 셀 **삭제** (D를 빠르게 두 번) |
# | **`Z`** | 삭제한 셀 되살리기 (Undo) |
# | **`L`** | 코드 줄 번호(Line Number) 표시/숨기기 |
#
# ## 3. 편집 및 커널 제어
# | 단축키 | 기능 |
# | :--- | :--- |
# | **`Ctrl + /`** | 선택한 줄 주석 처리/해제 |
# | **`Shift + M`** | 선택된 여러 셀을 하나로 합치기 |
# | **`I, I`** | 커널 실행 중단 (Interrupt - 무한 루프 시 사용) |
# | **`0, 0`** | 커널 재시작 (Restart) |
# | **`Esc` / `Enter`** | 명령 모드(파란색 테두리) / 편집 모드(커서 깜빡임) 전환 |
#
# ---
# > **💡 팁:** > - 코드 작성 중 함수 뒤에서 **`Shift + Tab`**을 누르면 함수 설명을 볼 수 있습니다.
# > - **`Tab`** 키를 누르면 자동 완성이 실행됩니다.

# %% [markdown]
# <!-- # ⌨️ VS Code Jupyter Notebook 핵심 단축키 요약
#
# 주피터 노트북은 **명령 모드(Esc)**와 **편집 모드(Enter)** 두 가지 상태가 있습니다. 이를 구분해서 사용하면 훨씬 빠릅니다.
#
# ---
#
# ## 1. 셀 실행 및 생성 (가장 중요)
# | 단축키 | 기능 |
# | :--- | :--- |
# | **`Shift + Enter`** | 현재 셀을 실행하고 **다음 셀로 이동** (없으면 생성) |
# | **`Ctrl + Enter`** | 현재 셀만 실행하고 해당 위치에 머무름 |
# | **`Alt + Enter`** | 현재 셀을 실행하고 **바로 아래에 새 셀 삽입** |
# | **`A`** | 현재 셀 **위에** 새 셀 추가 (Above) |
# | **`B`** | 현재 셀 **아래에** 새 셀 추가 (Below) |
#
# ## 2. 셀 타입 변경 및 관리
# | 단축키 | 기능 |
# | :--- | :--- |
# | **`M`** | 셀을 **마크다운(문서)** 모드로 변경 |
# | **`Y`** | 셀을 **코드(Python)** 모드로 변경 |
# | **`D, D`** | 선택한 셀 **삭제** (D를 빠르게 두 번) |
# | **`Z`** | 삭제한 셀 되살리기 (Undo) |
# | **`L`** | 코드 줄 번호(Line Number) 표시/숨기기 |
#
# ## 3. 편집 및 커널 제어
# | 단축키 | 기능 |
# | :--- | :--- |
# | **`Ctrl + /`** | 선택한 줄 주석 처리/해제 |
# | **`Shift + M`** | 선택된 여러 셀을 하나로 합치기 |
# | **`I, I`** | 커널 실행 중단 (Interrupt - 무한 루프 시 사용) |
# | **`0, 0`** | 커널 재시작 (Restart) |
# | **`Esc` / `Enter`** | 명령 모드(파란색 테두리) / 편집 모드(커서 깜빡임) 전환 |
#
# ---
# > **💡 팁:** > - 코드 작성 중 함수 뒤에서 **`Shift + Tab`**을 누르면 함수 설명을 볼 수 있습니다.
# > - **`Tab`** 키를 누르면 자동 완성이 실행됩니다. -->
